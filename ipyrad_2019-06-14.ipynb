# %% [markdown]
# # Thesis Pipeline
# This pipeline is modeled after:
# 1. [Carol Rowe's Allenrolfea analysis](https://digitalcommons.usu.edu/all_datasets/39/)
# 2. [emprical ipyrad API pedicularis](https://nbviewer.jupyter.org/github/dereneaton/ipyrad/blob/master/tests/cookbook-empirical-API-1-pedicularis.ipynb)
# 3. see Grundwald Lab [Poppr analysis](http://grunwaldlab.github.io/Population_Genetics_in_R/index.html) tutorial on github
# <br>
# <br>
# *to be updated with further population analysis as well* <br>

# %%
#required modules/programs/packages
#seaborn
#pandas
#numpy
#ipyparallel
#ipyrad

# %% [markdown]
# **Check `ipcluster` instance with a profile**<br>
# First we need to check our paralization

# %%
import ipyparallel as ipp
print 'ipyparallel version is', ipp.__version__
mpi1 = ipp.Client(profile="MPI60")
print 'MPI60 has',len(mpi1), 'cores'
# Out:
# ipyparallel version is 6.0.2
# MPI60 has 30 cores

# %% [markdown]
# ### *ipyrad*
# The only library we need to import is *ipyrad*. The import command is usually the first code called in a Python document to load any necessary packages. In the code below, we use a convenient trick in Python to tell it that we want to refer to ipyrad simply as ip. This saves us a little space since we might type the name many times. Below that, we use the print statement to print the version number of *ipyrad*. This is good practice to keep a record of which software version we are using. <br>
# <br>
# This guide and markdown is straight from the [*ipyrad* API user guide](https://ipyrad.readthedocs.io/API_user-guide.html) but will be using 2019_thesis data.

# %%
#requires ipyrad
import ipyrad as ip
print ip.__version__
# Out:
# 0.7.28

# %% [markdown]
# # IPYRAD FIRST STEPS
# runs steps 1, merge assemblys, and then runs step 2 <br>
# param files for this first bit should look something like this
# `
# lib1i12 = ip.Assembly("lib1i12")
# lib1i12.set_params('project_dir', '/fs/project/adams.1970/cardenas.61/2019_analysis')
# lib1i12.set_params('raw_fastq_path', '/fs/project/adams.1970/cardenas.61/2019_ddRADseq_data/CRC-RADseq/C_CarstensB_cc1_i12_V1C_1/*.fastq.gz')
# lib1i12.set_params('barcodes_path', './barcodes/lib1i12_barcodes.txt')
# lib1i12.set_params('assembly_method', 'denovo+reference')
# lib1i12.set_params('reference_sequence', './Tzet_genomic.fna')
# lib1i12.set_params('restriction_overhang', 'TGCAG, CGG')
# lib1i12.set_params('datatype', 'pairddrad')
# lib1i12.run("1",ipyclient=mpi1)
# lib1i12.stats
# ` <br>
# ### then you can merge, and modify the merged params file
# `fulldata = ip.merge("fulldata", [lib1i06,lib1i12,lib1i03,lib1i04,lib1i05,lib1i07,lib1i01,lib1i02,lib2i06,lib2i12,lib2i03])`<br>
#
#
# `lib2i03 = ip.Assembly("lib2i03")
# final = ip.Assembly("final")
# final.set_params('clust_threshold', '0.9')
# final.set_params('mindepth_statistical', '6')
# final.set_params('mindepth_majrule', '6')
# final.set_params('filter_adapters', '1')
# final.set_params('max_SNPs_locus', '20, 30')
# final.set_params('output_formats', '*')
# `<br>
# ### now you can run this merged dataset
# final.run("2",ipyclient=mpi1)

# %%
lib1i06 = ip.Assembly("lib1i06")
lib1i06.set_params('project_dir', '/fs/project/adams.1970/cardenas.61/2019_analysis') 
lib1i06.set_params('raw_fastq_path', '/fs/project/adams.1970/cardenas.61/2019_ddRADseq_data/CRC-RADseq/C_CarstensB_cc1_i6_V1C_1-1/*.fastq.gz') 
lib1i06.set_params('barcodes_path', './barcodes/lib1i06_barcodes.txt') 
lib1i06.set_params('assembly_method', 'denovo+reference')
lib1i06.set_params('reference_sequence', './Tzet_genomic.fna')
lib1i06.set_params('restriction_overhang', 'TGCAG, CGG')
lib1i06.set_params('datatype', 'pairddrad')
lib1i06.set_params('clust_threshold', '0.9')
lib1i06.set_params('mindepth_statistical', '6')
lib1i06.set_params('mindepth_majrule', '6')
lib1i06.set_params('filter_adapters', '1')
lib1i06.set_params('max_SNPs_locus', '20, 30')
lib1i06.set_params('output_formats', '*')
lib1i06.run("1",ipyclient=mpi1)

lib1i12 = ip.Assembly("lib1i12")
lib1i12.set_params('project_dir', '/fs/project/adams.1970/cardenas.61/2019_analysis') 
lib1i12.set_params('raw_fastq_path', '/fs/project/adams.1970/cardenas.61/2019_ddRADseq_data/CRC-RADseq/C_CarstensB_cc1_i12_V1C_1/*.fastq.gz') 
lib1i12.set_params('barcodes_path', './barcodes/lib1i12_barcodes.txt') 
lib1i12.set_params('assembly_method', 'denovo+reference')
lib1i12.set_params('reference_sequence', './Tzet_genomic.fna')
lib1i12.set_params('restriction_overhang', 'TGCAG, CGG')
lib1i12.set_params('datatype', 'pairddrad')
lib1i12.set_params('clust_threshold', '0.9')
lib1i12.set_params('mindepth_statistical', '6')
lib1i12.set_params('mindepth_majrule', '6')
lib1i12.set_params('filter_adapters', '1')
lib1i12.set_params('max_SNPs_locus', '20, 30')
lib1i12.set_params('output_formats', '*')
lib1i12.run("1",ipyclient=mpi1)

lib1i03 = ip.Assembly("lib1i03")
lib1i03.set_params('project_dir', '/fs/project/adams.1970/cardenas.61/2019_analysis') 
lib1i03.set_params('raw_fastq_path', '/fs/project/adams.1970/cardenas.61/2019_ddRADseq_data/CRC-RADseq/C_CarstensB_cc1_i3_V1C_1/*.fastq.gz') 
lib1i03.set_params('barcodes_path', './barcodes/lib1i03_barcodes.txt') 
lib1i03.set_params('assembly_method', 'denovo+reference')
lib1i03.set_params('reference_sequence', './Tzet_genomic.fna')
lib1i03.set_params('restriction_overhang', 'TGCAG, CGG')
lib1i03.set_params('datatype', 'pairddrad')
lib1i03.set_params('clust_threshold', '0.9')
lib1i03.set_params('mindepth_statistical', '6')
lib1i03.set_params('mindepth_majrule', '6')
lib1i03.set_params('filter_adapters', '1')
lib1i03.set_params('max_SNPs_locus', '20, 30')
lib1i03.set_params('output_formats', '*')
lib1i03.run("1",ipyclient=mpi1)


lib1i04 = ip.Assembly("lib1i04")
lib1i04.set_params('project_dir', '/fs/project/adams.1970/cardenas.61/2019_analysis') 
lib1i04.set_params('raw_fastq_path', '/fs/project/adams.1970/cardenas.61/2019_ddRADseq_data/CRC-RADseq/C_CarstensB_cc1_i4_V1C_1/*.fastq.gz') 
lib1i04.set_params('barcodes_path', './barcodes/lib1i04_barcodes.txt') 
lib1i04.set_params('assembly_method', 'denovo+reference')
lib1i04.set_params('reference_sequence', './Tzet_genomic.fna')
lib1i04.set_params('restriction_overhang', 'TGCAG, CGG')
lib1i04.set_params('datatype', 'pairddrad')
lib1i04.set_params('clust_threshold', '0.9')
lib1i04.set_params('mindepth_statistical', '6')
lib1i04.set_params('mindepth_majrule', '6')
lib1i04.set_params('filter_adapters', '1')
lib1i04.set_params('max_SNPs_locus', '20, 30')
lib1i04.set_params('output_formats', '*')
lib1i04.run("1",ipyclient=mpi1)


lib1i05 = ip.Assembly("lib1i05")
lib1i05.set_params('project_dir', '/fs/project/adams.1970/cardenas.61/2019_analysis') 
lib1i05.set_params('raw_fastq_path', '/fs/project/adams.1970/cardenas.61/2019_ddRADseq_data/CRC-RADseq/C_CarstensB_cc1_i4_V1C_1/*.fastq.gz') 
lib1i05.set_params('barcodes_path', './barcodes/lib1i05_barcodes.txt') 
lib1i05.set_params('assembly_method', 'denovo+reference')
lib1i05.set_params('reference_sequence', './Tzet_genomic.fna')
lib1i05.set_params('restriction_overhang', 'TGCAG, CGG')
lib1i05.set_params('datatype', 'pairddrad')
lib1i05.set_params('clust_threshold', '0.9')
lib1i05.set_params('mindepth_statistical', '6')
lib1i05.set_params('mindepth_majrule', '6')
lib1i05.set_params('filter_adapters', '1')
lib1i05.set_params('max_SNPs_locus', '20, 30')
lib1i05.set_params('output_formats', '*')
lib1i05.run("1",ipyclient=mpi1)


lib1i07 = ip.Assembly("lib1i07")
lib1i07.set_params('project_dir', '/fs/project/adams.1970/cardenas.61/2019_analysis') 
lib1i07.set_params('raw_fastq_path', '/fs/project/adams.1970/cardenas.61/2019_ddRADseq_data/CRC-RADseq/C_CarstensB_cc1_i6_V1C_1-2/*.fastq.gz') 
lib1i07.set_params('barcodes_path', './barcodes/lib1i07_barcodes.txt') 
lib1i07.set_params('assembly_method', 'denovo+reference')
lib1i07.set_params('reference_sequence', './Tzet_genomic.fna')
lib1i07.set_params('restriction_overhang', 'TGCAG, CGG')
lib1i07.set_params('datatype', 'pairddrad')
lib1i07.set_params('clust_threshold', '0.9')
lib1i07.set_params('mindepth_statistical', '6')
lib1i07.set_params('mindepth_majrule', '6')
lib1i07.set_params('filter_adapters', '1')
lib1i07.set_params('max_SNPs_locus', '20, 30')
lib1i07.set_params('output_formats', '*')
lib1i07.run("1",ipyclient=mpi1)


lib1i01 = ip.Assembly("lib1i01")
lib1i01.set_params('project_dir', '/fs/project/adams.1970/cardenas.61/2019_analysis') 
lib1i01.set_params('raw_fastq_path', '/fs/project/adams.1970/cardenas.61/2019_ddRADseq_data/CRC-RADseq/C_CarstensB_cc1_i1_V1C_1/*.fastq.gz') 
lib1i01.set_params('barcodes_path', './barcodes/lib1i01_barcodes.txt') 
lib1i01.set_params('assembly_method', 'denovo+reference')
lib1i01.set_params('reference_sequence', './Tzet_genomic.fna')
lib1i01.set_params('restriction_overhang', 'TGCAG, CGG')
lib1i01.set_params('datatype', 'pairddrad')
lib1i01.set_params('clust_threshold', '0.9')
lib1i01.set_params('mindepth_statistical', '6')
lib1i01.set_params('mindepth_majrule', '6')
lib1i01.set_params('filter_adapters', '1')
lib1i01.set_params('max_SNPs_locus', '20, 30')
lib1i01.set_params('output_formats', '*')
lib1i01.run("1",ipyclient=mpi1)


lib1i02 = ip.Assembly("lib1i02")
lib1i02.set_params('project_dir', '/fs/project/adams.1970/cardenas.61/2019_analysis') 
lib1i02.set_params('raw_fastq_path', '/fs/project/adams.1970/cardenas.61/2019_ddRADseq_data/CRC-RADseq/C_CarstensB_cc1_i2_V1C_1/*.fastq.gz') 
lib1i02.set_params('barcodes_path', './barcodes/lib1i02_barcodes.txt') 
lib1i02.set_params('assembly_method', 'denovo+reference')
lib1i02.set_params('reference_sequence', './Tzet_genomic.fna')
lib1i02.set_params('restriction_overhang', 'TGCAG, CGG')
lib1i02.set_params('datatype', 'pairddrad')
lib1i02.set_params('clust_threshold', '0.9')
lib1i02.set_params('mindepth_statistical', '6')
lib1i02.set_params('mindepth_majrule', '6')
lib1i02.set_params('filter_adapters', '1')
lib1i02.set_params('max_SNPs_locus', '20, 30')
lib1i02.set_params('output_formats', '*')
lib1i02.run("1",ipyclient=mpi1)
# Out:
# New Assembly: lib1i06
# Assembly: lib1i06
# [####################] 100%  chunking large files  | 0:06:47 | s1 |
# [####################] 100%  sorting reads         | 0:01:59 | s1 |
# [####################] 100%  writing/compressing   | 0:03:41 | s1 |
# New Assembly: lib1i12
# Assembly: lib1i12
# [####################] 100%  chunking large files  | 0:06:24 | s1 |
# [####################] 100%  sorting reads         | 0:01:44 | s1 |
# [####################] 100%  writing/compressing   | 0:03:34 | s1 |
# New Assembly: lib1i03
# Assembly: lib1i03
# [####################] 100%  chunking large files  | 0:03:03 | s1 |
# [####################] 100%  sorting reads         | 0:00:59 | s1 |
# [####################] 100%  writing/compressing   | 0:01:35 | s1 |
# New Assembly: lib1i04
# Assembly: lib1i04
# [####################] 100%  chunking large files  | 0:04:09 | s1 |
# [####################] 100%  sorting reads         | 0:01:13 | s1 |
# ...

# %%
lib2i06 = ip.Assembly("lib2i06")
lib2i06.set_params('project_dir', '/fs/project/adams.1970/cardenas.61/2019_analysis') 
lib2i06.set_params('raw_fastq_path', '/fs/project/adams.1970/cardenas.61/2019_ddRADseq_data/CRC-RADseq/C_CarstensB_cc2_i6_V1C_1/*.fastq.gz') 
lib2i06.set_params('barcodes_path', './barcodes/lib2i06_barcodes.txt') 
lib2i06.set_params('assembly_method', 'denovo+reference')
lib2i06.set_params('reference_sequence', './Tzet_genomic.fna')
lib2i06.set_params('restriction_overhang', 'TGCAG, CGG')
lib2i06.set_params('datatype', 'pairddrad')
lib2i06.set_params('clust_threshold', '0.9')
lib2i06.set_params('mindepth_statistical', '6')
lib2i06.set_params('mindepth_majrule', '6')
lib2i06.set_params('filter_adapters', '1')
lib2i06.set_params('max_SNPs_locus', '20, 30')
lib2i06.set_params('output_formats', '*')
lib2i06.run("1",ipyclient=mpi1)

lib2i12 = ip.Assembly("lib2i12")
lib2i12.set_params('project_dir', '/fs/project/adams.1970/cardenas.61/2019_analysis') 
lib2i12.set_params('raw_fastq_path', '/fs/project/adams.1970/cardenas.61/2019_ddRADseq_data/CRC-RADseq/C_CarstensB_cc2_i12_V1C_1/*.fastq.gz') 
lib2i12.set_params('barcodes_path', './barcodes/lib2i12_barcodes.txt') 
lib2i12.set_params('assembly_method', 'denovo+reference')
lib2i12.set_params('reference_sequence', './Tzet_genomic.fna')
lib2i12.set_params('restriction_overhang', 'TGCAG, CGG')
lib2i12.set_params('datatype', 'pairddrad')
lib2i12.set_params('clust_threshold', '0.9')
lib2i12.set_params('mindepth_statistical', '6')
lib2i12.set_params('mindepth_majrule', '6')
lib2i12.set_params('filter_adapters', '1')
lib2i12.set_params('max_SNPs_locus', '20, 30')
lib2i12.set_params('output_formats', '*')
lib2i12.run("1",ipyclient=mpi1)

lib2i03 = ip.Assembly("lib2i03")
lib2i03.set_params('project_dir', '/fs/project/adams.1970/cardenas.61/2019_analysis') 
lib2i03.set_params('raw_fastq_path', '/fs/project/adams.1970/cardenas.61/2019_ddRADseq_data/CRC-RADseq/C_CarstensB_cc2_i3_V1C_1/*.fastq.gz') 
lib2i03.set_params('barcodes_path', './barcodes/lib2i03_barcodes.txt') 
lib2i03.set_params('assembly_method', 'denovo+reference')
lib2i03.set_params('reference_sequence', './Tzet_genomic.fna')
lib2i03.set_params('restriction_overhang', 'TGCAG, CGG')
lib2i03.set_params('datatype', 'pairddrad')
lib2i03.set_params('clust_threshold', '0.9')
lib2i03.set_params('mindepth_statistical', '6')
lib2i03.set_params('mindepth_majrule', '6')
lib2i03.set_params('filter_adapters', '1')
lib2i03.set_params('max_SNPs_locus', '20, 30')
lib2i03.set_params('output_formats', '*')
lib2i03.run("1",ipyclient=mpi1)

# %%
fulldata = ip.merge("fulldata", [lib1i06,lib1i12,lib1i03,lib1i04,lib1i05,lib1i07,lib1i01,lib1i02,lib2i06,lib2i12,lib2i03])

# %%
! ls
lib1i02.stats
# Out:
# barcodes	lib1i04_fastqs	lib1i07.json	lib2i12_fastqs
# ipyrad.ipynb	lib1i04.json	lib1i12_fastqs	lib2i12.json
# ipyrad_log.txt	lib1i05_fastqs	lib1i12.json	MPI.ipynb
# lib1i01_fastqs	lib1i05.json	lib2i03_fastqs	reduced_samples
# lib1i01.json	lib1i06_fastqs	lib2i03.json	Tzet_genomic.fna
# lib1i03_fastqs	lib1i06.json	lib2i06_fastqs
# lib1i03.json	lib1i07_fastqs	lib2i06.json
#                state  reads_raw
# La_Seda_CC216      1    3564104
# La_Seda_CC245      1    2995561
# La_Seda_CC246      1    3468413
# La_Seda_CC248      1    2516839
# La_Seda_CC249      1    2922153
# La_Seda_CC250      1    2975286
# La_Seda_CC255      1    1601069
# La_Seda_CC256      1    2230013
# La_Seda_CC257      1    2786109
# La_Seda_CC258      1    2591101
# La_Seda_CC259      1    2366960
# La_Seda_CC260      1    2576534

# %%
#might help if you had the right damn directory!!!!
lib1i02 = ip.Assembly("lib1i02")
lib1i02.set_params('project_dir', '/fs/project/adams.1970/cardenas.61/2019_analysis') 
lib1i02.set_params('raw_fastq_path', '/fs/project/adams.1970/cardenas.61/2019_ddRADseq_data/CRC-RADseq/C_CarstensB_cc1_i2_V1C_1/*.fastq.gz') 
lib1i02.set_params('barcodes_path', './barcodes/lib1i02_barcodes.txt') 
lib1i02.set_params('assembly_method', 'denovo+reference')
lib1i02.set_params('reference_sequence', './Tzet_genomic.fna')
lib1i02.set_params('restriction_overhang', 'TGCAG, CGG')
lib1i02.set_params('datatype', 'pairddrad')
lib1i02.set_params('clust_threshold', '0.9')
lib1i02.set_params('mindepth_statistical', '6')
lib1i02.set_params('mindepth_majrule', '6')
lib1i02.set_params('filter_adapters', '1')
lib1i02.set_params('max_SNPs_locus', '20, 30')
lib1i02.set_params('output_formats', '*')
lib1i02.run("1",ipyclient=mpi1)
# Out:
# New Assembly: lib1i02
# Assembly: lib1i02
# [####################] 100%  chunking large files  | 0:03:52 | s1 |
# [####################] 100%  sorting reads         | 0:01:13 | s1 |
# [####################] 100%  writing/compressing   | 0:02:04 | s1 |

# %%
fulldata = ip.merge("fulldata", [lib1i06,lib1i12,lib1i03,lib1i04,lib1i05,lib1i07,lib1i01,lib1i02,lib2i06,lib2i12,lib2i03])
fulldata.get_params()
fulldata.stats
# Out:
# 0   assembly_name               fulldata
# 1   project_dir                 /fs/project/adams.1970/cardenas.61/2019_analysis
# 2   raw_fastq_path              Merged: lib1i06, lib1i12, lib1i03, lib1i04, lib1i05, lib1i07, lib1i01, lib1i02, lib2i06, lib2i12, lib2i03
# 3   barcodes_path               Merged: lib1i06, lib1i12, lib1i03, lib1i04, lib1i05, lib1i07, lib1i01, lib1i02, lib2i06, lib2i12, lib2i03
# 4   sorted_fastq_path           Merged: lib1i06, lib1i12, lib1i03, lib1i04, lib1i05, lib1i07, lib1i01, lib1i02, lib2i06, lib2i12, lib2i03
# 5   assembly_method             denovo+reference
# 6   reference_sequence          ./Tzet_genomic.fna
# 7   datatype                    pairddrad
# 8   restriction_overhang        ('TGCAG', 'CGG')
# 9   max_low_qual_bases          5
# 10  phred_Qscore_offset         33
# 11  mindepth_statistical        6
# 12  mindepth_majrule            6
# 13  maxdepth                    10000
# 14  clust_threshold             0.9
# ...

# %%
fulldata.set_params('filter_adapters', '2')
fulldata.set_params('min_samples_locus', '32')
fulldata.get_params()
# Out:
# 0   assembly_name               fulldata
# 1   project_dir                 /fs/project/adams.1970/cardenas.61/2019_analysis
# 2   raw_fastq_path              Merged: lib1i06, lib1i12, lib1i03, lib1i04, lib1i05, lib1i07, lib1i01, lib1i02, lib2i06, lib2i12, lib2i03
# 3   barcodes_path               Merged: lib1i06, lib1i12, lib1i03, lib1i04, lib1i05, lib1i07, lib1i01, lib1i02, lib2i06, lib2i12, lib2i03
# 4   sorted_fastq_path           Merged: lib1i06, lib1i12, lib1i03, lib1i04, lib1i05, lib1i07, lib1i01, lib1i02, lib2i06, lib2i12, lib2i03
# 5   assembly_method             denovo+reference
# 6   reference_sequence          ./Tzet_genomic.fna
# 7   datatype                    pairddrad
# 8   restriction_overhang        ('TGCAG', 'CGG')
# 9   max_low_qual_bases          5
# 10  phred_Qscore_offset         33
# 11  mindepth_statistical        6
# 12  mindepth_majrule            6
# 13  maxdepth                    10000
# 14  clust_threshold             0.9
# ...

# %% [markdown]
# # reduced data assembly
# fulldata.stats is going to be one run, but in this second one we are following Paulas idea and making a new data set with all samples with < 0.5 million reads<br>
# `Metro_Park_CC184	1	15963`<br>
# `Metro_Park_CC185	1	19655`<br>
# `Metro_Park_CC187	1	16969`<br>
# `Metro_Park_CC252	1	42792`<br>
# `Metro_Park_CC253	1	34129`<br>
# There are other samples w/ <1.0 million but for now lets keep it simple. We do not want to over filter our data.

# %%
reduced_data = ip.Assembly("reduced_data")
reduced_data.get_params() # need to change these parameters!
# Out:
# New Assembly: reduced_data
# 0   assembly_name               reduced_data
# 1   project_dir                 ./
# 2   raw_fastq_path
# 3   barcodes_path
# 4   sorted_fastq_path
# 5   assembly_method             denovo
# 6   reference_sequence
# 7   datatype                    rad
# 8   restriction_overhang        ('TGCAG', '')
# 9   max_low_qual_bases          5
# 10  phred_Qscore_offset         33
# 11  mindepth_statistical        6
# 12  mindepth_majrule            6
# 13  maxdepth                    10000
# 14  clust_threshold             0.85
# 15  max_barcode_mismatch        0
# 16  filter_adapters             0
# 17  filter_min_trim_len         35
# 18  max_alleles_consens         2
# 19  max_Ns_consens              (5, 5)
# 20  max_Hs_consens              (8, 8)
# 21  min_samples_locus           4
# 22  max_SNPs_locus              (20, 20)
# 23  max_Indels_locus            (8, 8)
# 24  max_shared_Hs_locus         0.5
# 25  trim_reads                  (0, 0, 0, 0)
# ...

# %%
reduced_data.set_params('sorted_fastq_path', '/fs/project/adams.1970/cardenas.61/2019_analysis/reduced_samples/*.fastq.gz')
reduced_data.set_params('project_dir', '/fs/project/adams.1970/cardenas.61/2019_analysis') 
reduced_data.set_params('assembly_method', 'denovo+reference')
reduced_data.set_params('reference_sequence', './Tzet_genomic.fna')
reduced_data.set_params('restriction_overhang', 'TGCAG, CGG')
reduced_data.set_params('datatype', 'pairddrad')
reduced_data.set_params('clust_threshold', '0.8')
reduced_data.set_params('mindepth_statistical', '5')
reduced_data.set_params('mindepth_majrule', '5')
reduced_data.set_params('min_samples_locus', '25')
reduced_data.set_params('filter_adapters', '1')
reduced_data.set_params('filter_min_trim_len', '100')
reduced_data.set_params('max_SNPs_locus', '20, 30')
reduced_data.set_params('output_formats', '*')
reduced_data.get_params()
# Out:
# 0   assembly_name               reduced_data
# 1   project_dir                 /fs/project/adams.1970/cardenas.61/2019_analysis
# 2   raw_fastq_path
# 3   barcodes_path
# 4   sorted_fastq_path           ./reduced_samples/*.fastq.gz
# 5   assembly_method             denovo+reference
# 6   reference_sequence          ./Tzet_genomic.fna
# 7   datatype                    pairddrad
# 8   restriction_overhang        ('TGCAG', 'CGG')
# 9   max_low_qual_bases          5
# 10  phred_Qscore_offset         33
# 11  mindepth_statistical        6
# 12  mindepth_majrule            6
# 13  maxdepth                    10000
# 14  clust_threshold             0.9
# 15  max_barcode_mismatch        0
# 16  filter_adapters             2
# 17  filter_min_trim_len         35
# 18  max_alleles_consens         2
# 19  max_Ns_consens              (5, 5)
# 20  max_Hs_consens              (8, 8)
# 21  min_samples_locus           32
# 22  max_SNPs_locus              (20, 30)
# ...

# %%
reduced_data.run("1",ipyclient=mpi1)
# Out:
# Assembly: reduced_data
# [####################] 100%  loading reads         | 0:00:45 | s1 |

# %%
reduced_data.run("2",ipyclient=mpi1)
# Out:
# Assembly: reduced_data
# [####################] 100%  processing reads      | 0:46:28 | s2 |

# %%
reduced_data.run("3",ipyclient=mpi1)
# Out:
# Assembly: reduced_data
# [####################] 100%  indexing reference    | 0:04:19 | s3 |
# [####################] 100%  dereplicating         | 0:16:13 | s3 |
# [#########           ]  46%  mapping               | 15:27:32 | s3 |

# %%
reduced_data.stats
# Out:
#                              state  reads_raw  reads_passed_filter  \
# Barro_Colorado_Island_CC269      3    2480813              2442232
# Barro_Colorado_Island_CC270      3    2499790              2453359
# Bird_Plot_CC132                  3    6260633              6146255
# Bird_Plot_CC133                  3    4580496              4478085
# Bird_Plot_CC134                  3    6632199              6500223
# Bird_Plot_CC135                  3   10120117              9910474
# Bird_Plot_CC136                  3    3980305              3900510
# Bird_Plot_CC137                  3    4062703              3958392
# Bird_Plot_CC138                  3    4023302              3906140
# Bird_Plot_CC139                  3    5095450              4966235
# Bird_Plot_CC143                  3    3684160              3610313
# Bird_Plot_CC144                  3    6571882              6518797
# Bird_Plot_CC145                  3    5981725              5930548
# ...

# %% [markdown]
# ### wheew that is bad
# we want our data to be more consistent, if you look at the s3_cluster_stats.txt in the directory step three creates (eg. `./*clust_0.9.txt`) you can see how much data is lost with a cluster threshold of 0.9! <br> <br>For example with sample CC134 we go from 490590 clusters total to 1709 clusters_hidepth. <br>
# Change this to 0.8 (we should have branched!)

# %%
# parameters for your next run
reduced_data.set_params('sorted_fastq_path', '/fs/project/adams.1970/cardenas.61/2019_analysis/reduced_samples/*.fastq.gz')
reduced_data.set_params('project_dir', '/fs/project/adams.1970/cardenas.61/2019_analysis') 
reduced_data.set_params('assembly_method', 'denovo+reference')
reduced_data.set_params('reference_sequence', './Tzet_genomic.fna')
reduced_data.set_params('restriction_overhang', 'TGCAG, CGG')
reduced_data.set_params('datatype', 'pairddrad')
reduced_data.set_params('clust_threshold', '0.8')
reduced_data.set_params('mindepth_statistical', '5')
reduced_data.set_params('mindepth_majrule', '5')
reduced_data.set_params('min_samples_locus', '25')
reduced_data.set_params('filter_adapters', '1')
reduced_data.set_params('filter_min_trim_len', '100')
reduced_data.set_params('max_SNPs_locus', '20, 30')
reduced_data.set_params('output_formats', '*')
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-2345c51fe2ab> in <module>()
# ----> 1 reduced_data.set_params('clust_threshold', '0.8')
#       2 reduced_data.set_params('mindepth_statistical', '5')
#       3 reduced_data.set_params('mindepth_majrule', '5')
#       4 reduced_data.set_params('trim_reads','(0, -5, 0, -10)')
#       5 reduced_data.set_params('filter_min_trim_len','90')
#
# NameError: name 'reduced_data' is not defined
